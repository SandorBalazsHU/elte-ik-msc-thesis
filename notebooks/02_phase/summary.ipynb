# %% [markdown]
# # Mérési notebook
# ---
# # **2. mérési fázis**. A	Modellek tesztelése teljes tanítással.
#
# #### **Cél**: Modellek tesztelése saját adathalmazon, majd saját modell ötletek tesztelése
# #### **Diplomamunka címe**: Fotográfiai témafelismerés neurális hálózatokkal nagy adathalmazon.
# #### **Készítette**: Sándor Balázs - AZA6NL
#
# ---
#
# ## MÉRÉSEK ÖSSZEGZÉSE
#
# ---

# %%
# 📦 Szükséges csomagok importálása
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# 📊 Adatok betöltése
data = {
    'Modell': ['ResNet50', 'DenseNet121', 'EfficientNet-B0', 'ConvNeXt-Tiny', 'ViT-B/16', 'Inception-v3', 'NASNet'],
    'Top-1 Accuracy': [0.7553, 0.7400, 0.7649, 0.7624, 0.7414, 0.7518, 0.7626],
    'Top-5 Accuracy': [0.9351, 0.9266, 0.9421, 0.9357, 0.9257, 0.9320, 0.9470],
    'Precision': [0.7110, 0.6811, 0.7130, 0.7168, 0.6935, 0.6963, 0.7180],
    'Recall': [0.6808, 0.6808, 0.6950, 0.6841, 0.6636, 0.6787, 0.6875],
    'F1-score': [0.6908, 0.6696, 0.7001, 0.6947, 0.6730, 0.6908, 0.6955],
    'Inference Time (sec)': [25.11, 25.23, 25.26, 25.67, 42.40, 25.11, 25.11]
}

df = pd.DataFrame(data)

df_sorted = df.sort_values('Top-1 Accuracy', ascending=False)

# 🎨 Stílus beállítása
sns.set(style="whitegrid")

# 📈 Top-1 Accuracy diagram
plt.figure(figsize=(10, 6))
sns.barplot(x='Top-1 Accuracy', y='Modell', data=df_sorted, palette='viridis')
plt.title('Top-1 Accuracy összehasonlítás')
plt.xlabel('Top-1 Accuracy')
plt.ylabel('Modell')
plt.xlim(0.7, 0.78)
plt.tight_layout()
plt.show()

df_sorted = df.sort_values('F1-score', ascending=False)

# 📈 F1-score diagram
plt.figure(figsize=(10, 6))
sns.barplot(x='F1-score', y='Modell', data=df_sorted, palette='magma')
plt.title('F1-score összehasonlítás')
plt.xlabel('F1-score')
plt.ylabel('Modell')
plt.xlim(0.66, 0.72)
plt.tight_layout()
plt.show()

df_sorted = df.sort_values('Inference Time (sec)', ascending=True)

# 📈 Inference Time diagram
plt.figure(figsize=(10, 6))
sns.barplot(x='Inference Time (sec)', y='Modell', data=df_sorted, palette='coolwarm')
plt.title('Inference Time összehasonlítás')
plt.xlabel('Inference Time (sec)')
plt.ylabel('Modell')
plt.xlim(24, 45)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-4-02b8ab1e0294>:26: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Top-1 Accuracy', y='Modell', data=df_sorted, palette='viridis')
# <ipython-input-4-02b8ab1e0294>:38: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='F1-score', y='Modell', data=df_sorted, palette='magma')
# <ipython-input-4-02b8ab1e0294>:50: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Inference Time (sec)', y='Modell', data=df_sorted, palette='coolwarm')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Adatok betöltése
data = {
    'Modell': ['ResNet50', 'DenseNet121', 'EfficientNet-B0', 'ConvNeXt-Tiny',
               'ViT-B-16', 'Inception-v3', 'NASNet'],
    'Top-1 Accuracy': [0.7553, 0.7400, 0.7649, 0.7624, 0.7414, 0.7518, 0.7626],
    'Top-5 Accuracy': [0.9351, 0.9266, 0.9421, 0.9357, 0.9257, 0.9320, 0.9470]
}

df = pd.DataFrame(data)

# Átalakítás hosszú formátumra
df_long = df.melt(id_vars='Modell', value_vars=['Top-1 Accuracy', 'Top-5 Accuracy'],
                  var_name='Metrika', value_name='Érték')

# Modell sorrend meghatározása Top-1 Accuracy alapján
model_order = df.sort_values('Top-1 Accuracy', ascending=False)['Modell']

# Diagram létrehozása
plt.figure(figsize=(10, 6))
sns.barplot(data=df_long, x='Érték', y='Modell', hue='Metrika', order=model_order, palette='Set2')
plt.title('Top-1 és Top-5 Accuracy összehasonlítása')
plt.xlabel('Érték')
plt.ylabel('Modell')
plt.legend(title='Metrika')
plt.tight_layout()
plt.show()

# %%
# Új adatok betöltése
data_metrics = {
    'Modell': ['ResNet50', 'DenseNet121', 'EfficientNet-B0', 'ConvNeXt-Tiny',
               'ViT-B-16', 'Inception-v3', 'NASNet'],
    'Precision': [0.7110, 0.6811, 0.7130, 0.7168, 0.6935, 0.6963, 0.7180],
    'Recall': [0.6808, 0.6808, 0.6950, 0.6841, 0.6636, 0.6787, 0.6875],
    'F1-score': [0.6908, 0.6696, 0.7001, 0.6947, 0.6730, 0.6908, 0.6955]
}

df_metrics = pd.DataFrame(data_metrics)

# Átalakítás hosszú formátumra
df_metrics_long = df_metrics.melt(id_vars='Modell', value_vars=['Precision', 'Recall', 'F1-score'],
                                  var_name='Metrika', value_name='Érték')

# Modell sorrend meghatározása F1-score alapján
model_order_metrics = df_metrics.sort_values('F1-score', ascending=False)['Modell']

# Diagram létrehozása
plt.figure(figsize=(10, 6))
sns.barplot(data=df_metrics_long, x='Érték', y='Modell', hue='Metrika', order=model_order_metrics, palette='Set1')
plt.title('Precision, Recall és F1-score összehasonlítása')
plt.xlabel('Érték')
plt.ylabel('Modell')
plt.legend(title='Metrika')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Adatok
data = {
    'Modell': [
        'EfficientNet-B0', 'NASNet', 'ConvNeXt-Tiny', 'ResNet50', 'Inception-v3', 'ViT-B/16', 'DenseNet121',
        'ResNet18 + Baseline fej', 'ResNet18 + Hybrid fej', 'ResNet18 + Deep fej', 'ResNet18 + Hybridv2 fej'
    ],
    'Top-1 Accuracy': [0.7649, 0.7626, 0.7624, 0.7553, 0.7518, 0.7414, 0.7400, 0.7303, 0.7276, 0.7247, 0.7236],
    'Top-5 Accuracy': [0.9421, 0.9470, 0.9357, 0.9351, 0.9320, 0.9257, 0.9266, 0.9099, 0.9074, 0.9000, 0.9011],
    'Precision': [0.7130, 0.7180, 0.7168, 0.7110, 0.6963, 0.6935, 0.6811, 0.6777, 0.6828, 0.6673, 0.6669],
    'Recall': [0.6950, 0.6875, 0.6841, 0.6808, 0.6787, 0.6636, 0.6808, 0.6490, 0.6369, 0.6336, 0.6391],
    'F1-score': [0.7001, 0.6955, 0.6947, 0.6908, 0.6908, 0.6730, 0.6696, 0.6568, 0.6536, 0.6455, 0.6469],
    'Inference Time (sec)': [25.26, 25.11, 25.67, 25.11, 25.11, 42.40, 25.23, 18.54, 16.13, 16.01, 15.62]
}

df = pd.DataFrame(data)

sns.set(style="whitegrid")

# Top-1 és Top-5 Accuracy
df_sorted = df.sort_values('Top-1 Accuracy', ascending=False)
df_long = df_sorted.melt(id_vars='Modell', value_vars=['Top-1 Accuracy', 'Top-5 Accuracy'], var_name='Metrika', value_name='Érték')

plt.figure(figsize=(12, 8))
sns.barplot(data=df_long, x='Érték', y='Modell', hue='Metrika', palette='Set2')
plt.title('Top-1 és Top-5 Accuracy összehasonlítása')
plt.xlabel('Pontosság')
plt.ylabel('Modell')
plt.legend(title='Metrika')
plt.tight_layout()
plt.show()

# %%
# Precision, Recall, F1-score
df_long2 = df_sorted.melt(id_vars='Modell', value_vars=['Precision', 'Recall', 'F1-score'], var_name='Metrika', value_name='Érték')

plt.figure(figsize=(12, 8))
sns.barplot(data=df_long2, x='Érték', y='Modell', hue='Metrika', palette='magma')
plt.title('Precision, Recall, F1-score összehasonlítása')
plt.xlabel('Érték')
plt.ylabel('Modell')
plt.legend(title='Metrika')
plt.tight_layout()
plt.show()

# %%
# Inference Time
df_sorted_inf = df.sort_values('Inference Time (sec)', ascending=True)

plt.figure(figsize=(12, 8))
sns.barplot(data=df_sorted_inf, x='Inference Time (sec)', y='Modell', palette='coolwarm')
plt.title('Inference Time (másodperc) összehasonlítása')
plt.xlabel('Idő (sec)')
plt.ylabel('Modell')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-9-7f647d22037d>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_sorted_inf, x='Inference Time (sec)', y='Modell', palette='coolwarm')

# %%
import matplotlib.pyplot as plt
import numpy as np

# Modellnevek
models = ['ResNet50', 'DenseNet121', 'EfficientNet-B0', 'ConvNeXt-Tiny', 'ViT-B-16', 'Inception-v3']

# Metrikák
top1_pt = [0.4698, 0.4498, 0.4802, 0.5048, 0.5308, 0.4763]
top1_ft = [0.7553, 0.7400, 0.7649, 0.7624, 0.7414, 0.7518]

top5_pt = [0.7962, 0.7806, 0.8217, 0.8471, 0.8582, 0.8008]
top5_ft = [0.9351, 0.9266, 0.9421, 0.9357, 0.9257, 0.9320]

precision_pt = [0.3934, 0.3874, 0.4137, 0.4917, 0.4629, 0.3833]
precision_ft = [0.7110, 0.6811, 0.7130, 0.7168, 0.6935, 0.6963]

recall_pt = [0.3797, 0.3611, 0.4039, 0.4369, 0.4419, 0.3896]
recall_ft = [0.6808, 0.6680, 0.6950, 0.6841, 0.6636, 0.6787]

f1_pt = [0.3592, 0.3408, 0.3829, 0.4194, 0.4307, 0.3683]
f1_ft = [0.6908, 0.6696, 0.7001, 0.6947, 0.6908, 0.6827]

# Ábrázolás
x = np.arange(len(models))
width = 0.35

fig, axs = plt.subplots(3, 1, figsize=(12, 18))

# Top-1 Accuracy
axs[0].bar(x - width/2, top1_pt, width, label='Pretrained')
axs[0].bar(x + width/2, top1_ft, width, label='Fine-tuned')
axs[0].set_ylabel('Top-1 Accuracy')
axs[0].set_title('Top-1 Accuracy összehasonlítás')
axs[0].set_xticks(x)
axs[0].set_xticklabels(models)
axs[0].legend()
axs[0].grid(True)

# Top-5 Accuracy
axs[1].bar(x - width/2, top5_pt, width, label='Pretrained')
axs[1].bar(x + width/2, top5_ft, width, label='Fine-tuned')
axs[1].set_ylabel('Top-5 Accuracy')
axs[1].set_title('Top-5 Accuracy összehasonlítás')
axs[1].set_xticks(x)
axs[1].set_xticklabels(models)
axs[1].legend()
axs[1].grid(True)

# Precision, Recall, F1-score
axs[2].bar(x - width, precision_pt, width/2, label='Precision PT')
axs[2].bar(x - width/2, precision_ft, width/2, label='Precision FT')
axs[2].bar(x, recall_pt, width/2, label='Recall PT')
axs[2].bar(x + width/2, recall_ft, width/2, label='Recall FT')
axs[2].bar(x + width, f1_pt, width/2, label='F1-score PT')
axs[2].bar(x + 1.5*width, f1_ft, width/2, label='F1-score FT')
axs[2].set_ylabel('Érték')
axs[2].set_title('Precision, Recall, F1-score összehasonlítás')
axs[2].set_xticks(x)
axs[2].set_xticklabels(models)
axs[2].legend()
axs[2].grid(True)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Modellek és metrikák
models = ['ResNet50', 'DenseNet121', 'EfficientNet-B0', 'ConvNeXt-Tiny', 'ViT-B-16', 'Inception-v3']
top1_pt = [0.4698, 0.4498, 0.4802, 0.5048, 0.5308, 0.4763]
top1_ft = [0.7553, 0.7400, 0.7649, 0.7624, 0.7414, 0.7518]
top5_pt = [0.7962, 0.7806, 0.8217, 0.8471, 0.8582, 0.8008]
top5_ft = [0.9351, 0.9266, 0.9421, 0.9357, 0.9257, 0.9320]

# Rendezés Top-1 FT szerint
sorted_indices = np.argsort(top1_ft)[::-1]
models_sorted = [models[i] for i in sorted_indices]
top1_pt_sorted = [top1_pt[i] for i in sorted_indices]
top1_ft_sorted = [top1_ft[i] for i in sorted_indices]
top5_pt_sorted = [top5_pt[i] for i in sorted_indices]
top5_ft_sorted = [top5_ft[i] for i in sorted_indices]

x = np.arange(len(models_sorted))
width = 0.2

fig, ax = plt.subplots(figsize=(12, 6))
ax.bar(x - width*1.5, top1_pt_sorted, width, label='Top-1 Pretrained')
ax.bar(x - width/2, top1_ft_sorted, width, label='Top-1 Fine-tuned')
ax.bar(x + width/2, top5_pt_sorted, width, label='Top-5 Pretrained')
ax.bar(x + width*1.5, top5_ft_sorted, width, label='Top-5 Fine-tuned')

ax.set_ylabel('Pontosság')
ax.set_title('Top-1 és Top-5 Pontosság összehasonlítása')
ax.set_xticks(x)
ax.set_xticklabels(models_sorted, rotation=45)
ax.legend()
plt.tight_layout()
plt.show()

# %%
# Metrikák
precision_pt = [0.3934, 0.3874, 0.4137, 0.4917, 0.4629, 0.3833]
precision_ft = [0.7110, 0.6811, 0.7130, 0.7168, 0.6935, 0.6963]
recall_pt = [0.3797, 0.3611, 0.4039, 0.4369, 0.4419, 0.3896]
recall_ft = [0.6808, 0.6680, 0.6950, 0.6841, 0.6636, 0.6787]
f1_pt = [0.3592, 0.3408, 0.3829, 0.4194, 0.4307, 0.3683]
f1_ft = [0.6908, 0.6696, 0.7001, 0.6947, 0.6908, 0.6827]

# Rendezés F1-score FT szerint
sorted_indices = np.argsort(f1_ft)[::-1]
models_sorted = [models[i] for i in sorted_indices]
precision_pt_sorted = [precision_pt[i] for i in sorted_indices]
precision_ft_sorted = [precision_ft[i] for i in sorted_indices]
recall_pt_sorted = [recall_pt[i] for i in sorted_indices]
recall_ft_sorted = [recall_ft[i] for i in sorted_indices]
f1_pt_sorted = [f1_pt[i] for i in sorted_indices]
f1_ft_sorted = [f1_ft[i] for i in sorted_indices]

x = np.arange(len(models_sorted))
width = 0.2

fig, ax = plt.subplots(figsize=(12, 6))
ax.bar(x - width*1.5, precision_pt_sorted, width, label='Precision Pretrained')
ax.bar(x - width/2, precision_ft_sorted, width, label='Precision Fine-tuned')
ax.bar(x + width/2, recall_pt_sorted, width, label='Recall Pretrained')
ax.bar(x + width*1.5, recall_ft_sorted, width, label='Recall Fine-tuned')

ax.set_ylabel('Érték')
ax.set_title('Precision és Recall összehasonlítása')
ax.set_xticks(x)
ax.set_xticklabels(models_sorted, rotation=45)
ax.legend()
plt.tight_layout()
plt.show()

# F1-score külön grafikonon
fig, ax = plt.subplots(figsize=(12, 6))
ax.bar(x - width/2, f1_pt_sorted, width, label='F1-score Pretrained')
ax.bar(x + width/2, f1_ft_sorted, width, label='F1-score Fine-tuned')

ax.set_ylabel('F1-score')
ax.set_title('F1-score összehasonlítása')
ax.set_xticks(x)
ax.set_xticklabels(models_sorted, rotation=45)
ax.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Adatok (kivonat)
models = ['ResNet50', 'DenseNet121', 'EfficientNet-B0', 'ConvNeXt-Tiny', 'ViT-B/16', 'Inception-v3', 'NASNet']
train_loss = [0.1144, 0.1791, 0.2928, 0.1389, 0.2083, 0.2234, 0.3706]
train_acc = [0.9651, 0.9451, 0.9066, 0.9577, 0.9355, 0.9502, 0.8858]
val_loss = [1.2761, 1.1960, 1.0443, 1.2230, 1.2559, 1.2737, 0.9542]
val_acc = [0.7517, 0.7377, 0.7658, 0.7591, 0.7426, 0.7524, 0.7598]

# Loss grafikon
plt.figure(figsize=(10,6))
plt.plot(models, train_loss, marker='o', label='Train Loss')
plt.plot(models, val_loss, marker='o', label='Validation Loss')
plt.title('Train vs Validation Loss (utolsó epoch)')
plt.ylabel('Loss')
plt.xticks(rotation=30)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Accuracy grafikon
plt.figure(figsize=(10,6))
plt.plot(models, train_acc, marker='o', label='Train Accuracy')
plt.plot(models, val_acc, marker='o', label='Validation Accuracy')
plt.title('Train vs Validation Accuracy (utolsó epoch)')
plt.ylabel('Accuracy')
plt.xticks(rotation=30)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# EPOCH szakaszok (NASNet külön, mert 3 epoch)
epochs_10 = list(range(1, 11))
epochs_3 = list(range(1, 4))

# EPOCH adatok (csak a végső loss/acc kivonatokkal)
resnet_train_loss = [1.4328,0.7961,0.5039,0.3260,0.2325,0.1836,0.1537,0.1356,0.1232,0.1144]
resnet_val_loss =   [1.0452,0.9251,0.9222,1.0148,1.0780,1.1245,1.1788,1.2189,1.2363,1.2761]
resnet_train_acc =  [0.6180,0.7653,0.8470,0.9004,0.9274,0.9437,0.9534,0.9584,0.9621,0.9651]
resnet_val_acc =    [0.6961,0.7359,0.7480,0.7506,0.7561,0.7534,0.7522,0.7509,0.7509,0.7517]

densenet_train_loss = [1.6432,1.0401,0.7765,0.5863,0.4442,0.3490,0.2790,0.2366,0.2048,0.1791]
densenet_val_loss =   [1.2331,1.0652,0.9971,1.0337,1.0095,1.0286,1.0950,1.1248,1.1491,1.1960]
densenet_train_acc =  [0.5788,0.7057,0.7751,0.8264,0.8663,0.8949,0.9152,0.9282,0.9372,0.9451]
densenet_val_acc =    [0.6573,0.7020,0.7206,0.7208,0.7380,0.7421,0.7380,0.7423,0.7373,0.7377]

efficientnet_train_loss = [1.7197,1.0839,0.8694,0.7178,0.6023,0.5112,0.4349,0.3823,0.3299,0.2928]
efficientnet_val_loss =   [1.1634,1.0030,0.9497,0.9296,0.9135,0.9244,0.9506,0.9799,1.0093,1.0443]
efficientnet_train_acc =  [0.5629,0.6881,0.7429,0.7834,0.8154,0.8407,0.8640,0.8796,0.8954,0.9066]
efficientnet_val_acc =    [0.6676,0.7094,0.7295,0.7429,0.7558,0.7586,0.7630,0.7661,0.7684,0.7658]

convnext_train_loss = [1.2237,0.7245,0.4842,0.3452,0.2654,0.2166,0.1899,0.1649,0.1532,0.1389]
convnext_val_loss =   [0.9806,0.9413,0.9336,0.9603,0.9909,1.0922,1.1023,1.1498,1.1599,1.2230]
convnext_train_acc =  [0.6582,0.7799,0.8492,0.8915,0.9177,0.9331,0.9412,0.9491,0.9527,0.9577]
convnext_val_acc =    [0.7127,0.7287,0.7513,0.7585,0.7660,0.7504,0.7648,0.7657,0.7617,0.7591]

vit_train_loss = [1.2851,0.8488,0.6250,0.4766,0.3783,0.3202,0.2771,0.2482,0.2237,0.2083]
vit_val_loss =   [1.1000,0.9895,0.9986,1.0406,1.0650,1.1107,1.1609,1.1802,1.2074,1.2559]
vit_train_acc =  [0.6443,0.7472,0.8080,0.8511,0.8815,0.9000,0.9137,0.9230,0.9297,0.9355]
vit_val_acc =    [0.6794,0.7195,0.7340,0.7300,0.7371,0.7365,0.7377,0.7378,0.7470,0.7426]

inception_train_loss = [2.1448,1.2943,0.9102,0.6552,0.4818,0.3864,0.3178,0.2772,0.2435,0.2234]
inception_val_loss =   [1.1183,0.9889,0.9692,1.0133,1.0527,1.1098,1.1535,1.1772,1.2565,1.2737]
inception_train_acc =  [0.6042,0.7373,0.8097,0.8592,0.8953,0.9153,0.9298,0.9386,0.9464,0.9502]
inception_val_acc =    [0.6850,0.7210,0.7399,0.7404,0.7486,0.7539,0.7513,0.7514,0.7496,0.7524]

nasnet_train_loss = [1.2301,0.6347,0.3706]
nasnet_val_loss =   [0.9508,0.9009,0.9542]
nasnet_train_acc =  [0.6617,0.8083,0.8858]
nasnet_val_acc =    [0.7256,0.7561,0.7598]

# Loss grafikon
plt.figure(figsize=(12,6))
plt.plot(epochs_10, resnet_train_loss, label='ResNet50 Train Loss', linestyle='-')
plt.plot(epochs_10, resnet_val_loss, label='ResNet50 Val Loss', linestyle='--')
plt.plot(epochs_10, densenet_train_loss, label='DenseNet121 Train Loss', linestyle='-')
plt.plot(epochs_10, densenet_val_loss, label='DenseNet121 Val Loss', linestyle='--')
plt.plot(epochs_10, efficientnet_train_loss, label='EfficientNet-B0 Train Loss', linestyle='-')
plt.plot(epochs_10, efficientnet_val_loss, label='EfficientNet-B0 Val Loss', linestyle='--')
plt.plot(epochs_10, convnext_train_loss, label='ConvNeXt-Tiny Train Loss', linestyle='-')
plt.plot(epochs_10, convnext_val_loss, label='ConvNeXt-Tiny Val Loss', linestyle='--')
plt.plot(epochs_10, vit_train_loss, label='ViT-B/16 Train Loss', linestyle='-')
plt.plot(epochs_10, vit_val_loss, label='ViT-B/16 Val Loss', linestyle='--')
plt.plot(epochs_10, inception_train_loss, label='Inception-v3 Train Loss', linestyle='-')
plt.plot(epochs_10, inception_val_loss, label='Inception-v3 Val Loss', linestyle='--')
plt.plot(epochs_3, nasnet_train_loss, label='NASNet Train Loss', linestyle='-')
plt.plot(epochs_3, nasnet_val_loss, label='NASNet Val Loss', linestyle='--')

plt.title('Train Loss és Validation Loss változás (Epoch-ok szerint)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# Accuracy grafikon
plt.figure(figsize=(12,6))
plt.plot(epochs_10, resnet_train_acc, label='ResNet50 Train Acc', linestyle='-')
plt.plot(epochs_10, resnet_val_acc, label='ResNet50 Val Acc', linestyle='--')
plt.plot(epochs_10, densenet_train_acc, label='DenseNet121 Train Acc', linestyle='-')
plt.plot(epochs_10, densenet_val_acc, label='DenseNet121 Val Acc', linestyle='--')
plt.plot(epochs_10, efficientnet_train_acc, label='EfficientNet-B0 Train Acc', linestyle='-')
plt.plot(epochs_10, efficientnet_val_acc, label='EfficientNet-B0 Val Acc', linestyle='--')
plt.plot(epochs_10, convnext_train_acc, label='ConvNeXt-Tiny Train Acc', linestyle='-')
plt.plot(epochs_10, convnext_val_acc, label='ConvNeXt-Tiny Val Acc', linestyle='--')
plt.plot(epochs_10, vit_train_acc, label='ViT-B/16 Train Acc', linestyle='-')
plt.plot(epochs_10, vit_val_acc, label='ViT-B/16 Val Acc', linestyle='--')
plt.plot(epochs_10, inception_train_acc, label='Inception-v3 Train Acc', linestyle='-')
plt.plot(epochs_10, inception_val_acc, label='Inception-v3 Val Acc', linestyle='--')
plt.plot(epochs_3, nasnet_train_acc, label='NASNet Train Acc', linestyle='-')
plt.plot(epochs_3, nasnet_val_acc, label='NASNet Val Acc', linestyle='--')

plt.title('Train Accuracy és Validation Accuracy változás (Epoch-ok szerint)')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
